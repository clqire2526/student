# %% [markdown]
# ---
# layout: post
# title: My Blog
# description: Claire's Blog
# permalink: /mycsblog
# ---

# %% [markdown]
# ## First Few Weeks of CSSE 🖥
#
# Creating accounts, setting up repositories on Github, going into Kasm, setting up files on vs code
#
# - creating Github accounts- linked to kasm and open coding society
#
# - forking repositories on Github
#
# - Setting up kasm, git cloning
#
# ## Learning Javascript 🧑‍💻
#
# - Learning the basics and hows things work
#
#     - Booleans, Variables, Classes, Constructors, Functions etc.
#
# ## Gamify Quest (Haunted Mansion Game) 👻🏚
#
# - Made the background
#
# - Brainstorming, helped organize the idea
#
# - Did a lot of trouble shooting in the early stages of game
#
# - Testing out and communicating errors
#
# ### If there were more time... ⏰
#
# If there were more time, I would
#
# - make the enter mechanism more convenient for player
#
# - make memory game a little more complicated (change pattern every time)
#
# - change it so that when playing memory game, player needs to touch the gravestone to get the point
#
# ## Analytics
#
# <img width="902" height="529" alt="Image" src="https://github.com/user-attachments/assets/4232151f-04d5-4e17-9f56-9754b1629c9b" />
#
# <img width="902" height="529" alt="Image" src="https://github.com/user-attachments/assets/83b7d79f-8ae6-4f5d-872f-700657a8a2f7" />
#
# <img width="902" height="529" alt="Image" src="https://github.com/user-attachments/assets/c65151fe-4dc5-4cee-8381-10419627fd7d" />
